# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('Cleaned_dataset.csv')

# %%
df.sample(4)
# Out:
#       EmployeeID  Age  TotalWorkingYears  MonthlyIncome  OverTime  \
# 738      1212094   42              0.525       0.910690         0
# 607      1282527   43              0.550       0.850448         0
# 1429     1818407   25              0.150       0.205266         1
# 1194     1119867   20              0.050       0.090521         0
#
#       DistanceFromHome  YearsAtCompany  MonthlyRate  JobInvolvement  JobRole  \
# 738           0.142857           0.025     0.227906        0.666667        3
# 607           0.464286           0.100     0.124714        0.666667        3
# 1429          0.250000           0.125     0.465368        0.666667        1
# 1194          0.285714           0.050     0.762417        0.666667        0
#
#       JobLevel  YearsInCurrentRole  YearsSinceLastPromotion  \
# 738       1.00            0.000000                        0
# 607       0.75            0.055556                        1
# 1429      0.25            0.166667                        0
# ...

# %%
rows, columns = df.shape
print(f'Rows    : {rows}')
print(f'Columns : {columns}')
df.describe()
# Out:
# Rows    : 1676
# Columns : 20
#          EmployeeID          Age  TotalWorkingYears  MonthlyIncome  \
# count  1.676000e+03  1676.000000        1676.000000    1676.000000
# mean   1.456796e+06    36.866348           0.283473       0.290022
# std    2.487486e+05     9.129126           0.195875       0.248997
# min    1.025177e+06    18.000000           0.000000       0.000000
# 25%    1.235832e+06    30.000000           0.150000       0.101066
# 50%    1.464606e+06    36.000000           0.250000       0.204845
# 75%    1.667992e+06    43.000000           0.375000       0.388165
# max    1.886378e+06    60.000000           1.000000       1.000000
#
#           OverTime  DistanceFromHome  YearsAtCompany  MonthlyRate  \
# count  1676.000000       1676.000000     1676.000000  1676.000000
# mean      0.284010          0.293641        0.175835     0.489581
# std       0.451076          0.291361        0.152475     0.286644
# ...

# %%
y = df['Attrition'] # test data
X = df.drop(['Attrition'], axis=1) #training data

print(f'Training data: {X.columns}\n')
print(f'Testing data : {y.name}')
# Out:
# Training data: Index(['EmployeeID', 'Age', 'TotalWorkingYears', 'MonthlyIncome', 'OverTime',
#        'DistanceFromHome', 'YearsAtCompany', 'MonthlyRate', 'JobInvolvement',
#        'JobRole', 'JobLevel', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'EnvironmentSatisfaction', 'Shift',
#        'WorkLifeBalance', 'PercentSalaryHike', 'MaritalStatus'],
#       dtype='object')
#
# Testing data : Attrition

# %%
y.unique()
# Out:
# array([0, 1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
print(f'X_train : {X_train.shape}')
print(f'X_test  : {X_test.shape}\n')
print(f'y_train : {y_train.shape}')
print(f'y_test  : {y_test.shape}')
# Out:
# X_train : (1340, 19)
# X_test  : (336, 19)
#
# y_train : (1340,)
# y_test  : (336,)

# %%
# Before RandomForestClassifier

rfc_model = RandomForestClassifier(n_estimators=100, random_state=101)
rfc_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=101)

# %%
train_score_before_hpt = rfc_model.score(X_train, y_train)
test_score_brefore_hpt = rfc_model.score(X_test, y_test)

# %%
print(f'Train score: {train_score_before_hpt:.3f}')
print(f'Test score : {test_score_brefore_hpt:.3f}')
# Out:
# Train score: 1.0
# Test score : 0.9196428571428571

# %%
# Number of trees in random forest
random_values = np.linspace(50, 101, 10) 
# values = []
# for i in random_values: 
#     values.append(int(i))
# n_estimators = [values]
n_estimators = [int(i) for i in random_values]

# Number of features to consider at every split
max_features = ['log2', 'sqrt']

# Maximum number of levels in tree
max_depth = [5, 10]

# Minimum number of samples required to split a node
min_samples_split = [2, 5]

# Minimum number of samples reqiured at each leaf node
min_sample_leaf = [10, 20]

# Method of selecting samples for training each tree
bootsstrap = [True, False]

# %%
param_grid = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_sample_leaf,
    'bootstrap': bootsstrap
}
print(param_grid)
# Out:
# {'n_estimators': [50, 55, 61, 67, 72, 78, 84, 89, 95, 101], 'max_features': ['log2', 'sqrt'], 'max_depth': [5, 10], 'min_samples_split': [2, 5], 'min_samples_leaf': [10, 20], 'bootstrap': [True, False]}

# %%
rfc = RandomForestClassifier(101)

# %%
from sklearn.model_selection import GridSearchCV
rfc_grid = GridSearchCV(rfc, param_grid, cv=3, verbose=2, n_jobs=4, error_score='raise') # estimator, param_grid, cv, verbose, n_jobs
# 'verbose' gives information about the process while the fitting is happening
#  'n_jobs' use the number of cores in the cpu for this process

# %%
rfc_grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 320 candidates, totalling 960 fits
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\miniconda3\envs\virt2-3.10\lib\site-packages\IPython\core\formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~\miniconda3\envs\virt2-3.10\lib\site-packages\sklearn\utils\_repr_html\base.py:151, in ReprHTMLMixin._repr_mimebundle_(self, **kwargs)
#     149 output = {"text/plain": repr(self)}
#     150 if get_config()["display"] == "diagram":
# --> 151     output["text/html"] = self._html_repr()
#     152 return output
#
# ...

# %%
rfc_grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 10,
#  'max_features': 'log2',
#  'min_samples_leaf': 10,
#  'min_samples_split': 2,
#  'n_estimators': 89}

# %%
train_score_after_hpt = rfc_grid.score(X_train, y_train)
test_score_after_hpt = rfc_grid.score(X_test, y_test)

# %%
print(f'Train Accuracy Before Hyperparameter Tuning: {train_score_before_hpt:.3f}        # Overfitting is clealy visible')
print(f'Test Accuracy Before Hyperparameter Tuning : {test_score_brefore_hpt:.3f}\n')

print(f'Train Accuracy After Hyperparameter Tuning: {train_score_after_hpt:.3f}         # Minimized overfitting')
print(f'Test Accuracy After Hyperparameter Tuning : {test_score_after_hpt:.3f}')
# Out:
# Train Accuracy Before Hyperparameter Tuning: 1.000        # Overfitting is clealy visible
# Test Accuracy Before Hyperparameter Tuning : 0.920
#
# Train Accuracy After Hyperparameter Tuning: 0.934         # Minimized overfitting
# Test Accuracy After Hyperparameter Tuning : 0.899

# %%
difference_before = train_score_before_hpt - test_score_brefore_hpt
difference_after = train_score_after_hpt - test_score_after_hpt
print(f'Difference between train and test cases before HPT: {difference_before:.4f}')
print(f'Difference between train and test cases after HPT: {difference_after:.4f}\n')

print(f'Accuracy improvement : {difference_before - difference_after:.4f}')
# Out:
# Difference between train and test cases before HPT: 0.0804
# Difference between train and test cases after HPT: 0.0348
#
# Accuracy improvement : 0.0456

# %% [raw]
# The conclusion is Hyperparameter tunining reduces over fitting and increases the accuracy by 0.0456
