# %%
import pandas as pd

# %%
testing = pd.read_csv('watson_healthcare_modified.csv')

# %%
testing.drop('Attrition', axis=1, inplace=True)
print(f'testing set shape: {testing.shape}')
testing.head(4)
# Out:
# testing set shape: (1676, 34)
#    EmployeeID  Age     BusinessTravel  DailyRate  Department  \
# 0     1313919   41      Travel_Rarely       1102  Cardiology
# 1     1200302   49  Travel_Frequently        279   Maternity
# 2     1060315   37      Travel_Rarely       1373   Maternity
# 3     1272912   33  Travel_Frequently       1392   Maternity
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          2  Life Sciences              1
# 1                 8          1  Life Sciences              1
# 2                 2          2          Other              1
# 3                 3          4  Life Sciences              1
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        2  ...                        1             80
# 1                        3  ...                        4             80
# 2                        4  ...                        2             80
# ...

# %%
testing.to_csv('csv_for_testing.csv', index=False)
