# %%
import pandas as pd

# %%
data = pd.read_csv('watson_healthcare_modified.csv')
data.shape
# Out:
# (1676, 35)

# %%
data.sample(4)
# Out:
#       EmployeeID  Age Attrition BusinessTravel  DailyRate Department  \
# 994      1526314   27       Yes  Travel_Rarely        135  Maternity
# 856      1500784   29       Yes  Travel_Rarely        942  Maternity
# 560      1269152   33       Yes  Travel_Rarely        527  Maternity
# 1494     1469038   42        No  Travel_Rarely        933  Maternity
#
#       DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 994                 17          4  Life Sciences              1  ...
# 856                 15          1  Life Sciences              1  ...
# 560                  1          4          Other              1  ...
# 1494                29          3  Life Sciences              1  ...
#
#       RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 994                          4            80      0                  8
# 856                          1            80      1                  6
# ...

# %%
data['Age'].dtype
# Out:
# dtype('int64')
