# %%
import pandas as pd

# %%
original_data = pd.read_csv('watson_healthcare_modified.csv')
data = original_data.copy()
data.shape
# Out:
# (1676, 35)

# %%
data.sample(4)
# Out:
#       EmployeeID  Age Attrition BusinessTravel  DailyRate  Department  \
# 1463     1417927   27        No  Travel_Rarely        155  Cardiology
# 1272     1612699   51        No  Travel_Rarely        942   Neurology
# 673      1213565   31        No  Travel_Rarely        154  Cardiology
# 688      1142961   31        No  Travel_Rarely        616   Maternity
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  ...  \
# 1463                 4          3     Life Sciences              1  ...
# 1272                 3          3  Technical Degree              1  ...
# 673                  7          4     Life Sciences              1  ...
# 688                 12          3           Medical              1  ...
#
#       RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 1463                         2            80      1                  6
# 1272                         4            80      0                 15
# ...

# %%
data['Age'].dtype
# Out:
# dtype('int64')

# %%
data_int64 = data.select_dtypes(include='int64') # selects all the columns with data type 'int64'
data_objs = data.select_dtypes(exclude='int64') 
data_objs.dtypes
# Out:
# Attrition         object
# BusinessTravel    object
# Department        object
# EducationField    object
# Gender            object
# JobRole           object
# MaritalStatus     object
# Over18            object
# OverTime          object
# dtype: object

# %% [markdown]
# #### Cleaning Corrupted Data

# %%
# verification of data in object columns
print(f'Attrition      = {data.Attrition.unique()}')
print(f'BusinessTravel = {data.BusinessTravel.unique()}')
print(f'Department     = {data.Department.unique()}')
print(f'Gender         = {data.Gender.unique()}')
print(f'JobRole        = {data.JobRole.unique()}')
print(f'Over18         = {data.Over18.unique()}')
print(f'OverTime       = {data.OverTime.unique()}')
# Out:
# Attrition      = ['No' 'Yes']
# BusinessTravel = ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department     = ['Cardiology' 'Maternity' 'Neurology']
# Gender         = ['Female' 'Male']
# JobRole        = ['Nurse' 'Other' 'Therapist' 'Administrative' 'Admin']
# Over18         = ['Y']
# OverTime       = ['Yes' 'No']

# %% [markdown]
# #### Cleaning NaN Values

# %%
data_int64.isna().any()
# Out:
# EmployeeID                  False
# Age                         False
# DailyRate                   False
# DistanceFromHome            False
# Education                   False
# EmployeeCount               False
# EnvironmentSatisfaction     False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobSatisfaction             False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# Shift                       False
# TotalWorkingYears           False
# TrainingTimesLastYear       False
# WorkLifeBalance             False
# YearsAtCompany              False
# YearsInCurrentRole          False
# YearsSinceLastPromotion     False
# YearsWithCurrManager        False
# dtype: bool

# %%
data_objs.isna().any()
# Out:
# Attrition         False
# BusinessTravel    False
# Department        False
# EducationField    False
# Gender            False
# JobRole           False
# MaritalStatus     False
# Over18            False
# OverTime          False
# dtype: bool

# %% [markdown]
# #### Cleaning Duplicates

# %%
data.duplicated().any()
# Out:
# np.False_
