# %%
import pandas as pd

# %%
data = pd.read_csv('watson_healthcare_modified.csv')
data.shape
# Out:
# (1676, 35)

# %%
data.sample(4)
# Out:
#       EmployeeID  Age Attrition     BusinessTravel  DailyRate  Department  \
# 1080     1161882   40       Yes      Travel_Rarely        676   Maternity
# 452      1636995   26       Yes  Travel_Frequently        426   Neurology
# 683      1840229   26        No  Travel_Frequently       1283  Cardiology
# 1198     1082389   23       Yes      Travel_Rarely       1320   Maternity
#
#       DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 1080                 9          4  Life Sciences              1  ...
# 452                 17          4  Life Sciences              1  ...
# 683                  1          3        Medical              1  ...
# 1198                 8          1        Medical              1  ...
#
#       RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 1080                         2            80      0                 15
# 452                          2            80      1                  8
# ...
