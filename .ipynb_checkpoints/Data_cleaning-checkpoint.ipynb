# %%
import pandas as pd

# %%
data = pd.read_csv('watson_healthcare_modified.csv')
data.shape
# Out:
# (1676, 35)

# %%
data.sample(4)
# Out:
#       EmployeeID  Age Attrition BusinessTravel  DailyRate Department  \
# 1161     1294986   40        No  Travel_Rarely        448  Maternity
# 372      1078791   35        No  Travel_Rarely        755  Maternity
# 855      1795477   53        No  Travel_Rarely       1223  Neurology
# 848      1710657   56        No  Travel_Rarely        718  Neurology
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  ...  \
# 1161                16          3     Life Sciences              1  ...
# 372                  9          4     Life Sciences              1  ...
# 855                  7          2           Medical              1  ...
# 848                  4          4  Technical Degree              1  ...
#
#       RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 1161                         4            80      0                 18
# 372                          3            80      0                 10
# ...

# %%
data['Age'].dtype
# Out:
# dtype('int64')
