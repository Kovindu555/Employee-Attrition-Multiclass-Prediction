# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Cleaned_dataset.csv')

# %%
X = df.drop(['EmployeeID', 'Attrition'], axis=1)
y = df['Attrition']

# %%
X.shape
# Out:
# (1676, 18)

# %%
y.shape
# Out:
# (1676,)

# %%
from sklearn.model_selection import cross_val_score as cvs

# %%
# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
cv_score_knn = cvs(knn, X, y, cv=10).mean()
print(f'Cross validation Score using KNN: {cv_score_knn:.3f}')
# Out:
# Cross validation Score using KNN: 0.900

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
cv_score_rfc = cvs(rfc, X, y, cv=10).mean()
print(f'Cross validation Score using RFC: {cv_score_rfc:.3f}')
# Out:
# Cross validation Score using RFC: 0.912

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
cv_score_gnb = cvs(gnb, X, y, cv=10).mean()
print(f'Cross validation Score using GNB: {cv_score_gnb:.3f}')
# Out:
# Cross validation Score using GNB: 0.746

# %%
# Support vector machine
from sklearn.svm import SVC
svm = SVC()
cv_score_svm = cvs(svm, X, y, cv=10).mean()
print(f'Cross validation Score using SVM: {cv_score_svm:.3f}')
# Out:
# Cross validation Score using SVM: 0.881

# %%
cv_score_list = [cv_score_knn, cv_score_rfc, cv_score_gnb, cv_score_svm]

cv_dictionary = {cv_score_knn : 'KNN', cv_score_rfc: 'RFC', cv_score_gnb: 'GNB', cv_score_svm: 'SVM'}

for score, technique in cv_dictionary.items():
    print(f'{technique} : {score:.3f}')

max_cv_value = max(cv_score_list)
print(f'\nMost suitable technique is << {cv_dictionary[max_cv_value]} >> and value is : {max_cv_value:.3f}')
# Out:
# KNN : 0.900
# RFC : 0.912
# GNB : 0.746
# SVM : 0.881
#
# Most suitable technique is << RFC >> and value is : 0.912
