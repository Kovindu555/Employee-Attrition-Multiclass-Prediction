# %%
import pandas as pd

# %%
data = pd.read_csv('watson_healthcare_modified.csv')
data.sample(4)
# Out:
#       EmployeeID  Age Attrition BusinessTravel  DailyRate  Department  \
# 1544     1159699   30        No  Travel_Rarely        201   Maternity
# 1633     1698428   27        No  Travel_Rarely        975   Maternity
# 1399     1583381   39        No  Travel_Rarely        119  Cardiology
# 264      1622255   28       Yes  Travel_Rarely        529   Maternity
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  ...  \
# 1544                 5          3  Technical Degree              1  ...
# 1633                 7          3           Medical              1  ...
# 1399                15          4         Marketing              1  ...
# 264                  2          4     Life Sciences              1  ...
#
#       RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 1544                         4            80      1                  8
# 1633                         1            80      0                  9
# 1399                         1            80      0                 21
# 264                          3            80      0                  5
#
#       TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 1544                      3               3               3
# 1633                      2               1               7
# 1399                      3               3              20
# 264                       5               1               0
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1544                  2                        2                     2
# 1633                  6                        0                     7
# 1399                  8                       11                    10
# 264                   0                        0                     0
#
# [4 rows x 35 columns]

# %%
data.shape
# Out:
# (1676, 35)

# %%
data.select_dtypes(include='object')
# Out:
#      Attrition     BusinessTravel  Department    EducationField  Gender  \
# 0           No      Travel_Rarely  Cardiology     Life Sciences  Female
# 1           No  Travel_Frequently   Maternity     Life Sciences    Male
# 2          Yes      Travel_Rarely   Maternity             Other    Male
# 3           No  Travel_Frequently   Maternity     Life Sciences  Female
# 4           No      Travel_Rarely   Maternity           Medical    Male
# ...        ...                ...         ...               ...     ...
# 1671       Yes      Travel_Rarely   Neurology  Technical Degree    Male
# 1672        No      Travel_Rarely  Cardiology         Marketing  Female
# 1673        No      Travel_Rarely   Maternity     Life Sciences  Female
# 1674        No      Travel_Rarely   Neurology     Life Sciences  Female
# 1675        No      Travel_Rarely  Cardiology           Medical  Female
#
#         JobRole MaritalStatus Over18 OverTime
# 0         Nurse        Single      Y      Yes
# 1         Other       Married      Y       No
# 2         Nurse        Single      Y      Yes
# 3         Other       Married      Y      Yes
# 4         Nurse       Married      Y       No
# ...         ...           ...    ...      ...
# 1671      Nurse        Single      Y      Yes
# 1672      Nurse       Married      Y      Yes
# 1673      Other        Single      Y       No
# 1674  Therapist       Married      Y       No
# 1675      Nurse        Single      Y       No
#
# [1676 rows x 9 columns]

# %%
df = data.copy()
df.tail(5)
# Out:
#       EmployeeID  Age Attrition BusinessTravel  DailyRate  Department  \
# 1671     1117656   26       Yes  Travel_Rarely        471   Neurology
# 1672     1152327   46        No  Travel_Rarely       1125  Cardiology
# 1673     1812428   20        No  Travel_Rarely        959   Maternity
# 1674     1812429   39        No  Travel_Rarely        466   Neurology
# 1675     1152329   27        No  Travel_Rarely        511  Cardiology
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  ...  \
# 1671                24          3  Technical Degree              1  ...
# 1672                10          3         Marketing              1  ...
# 1673                 1          3     Life Sciences              1  ...
# 1674                 1          1     Life Sciences              1  ...
# 1675                 2          2           Medical              1  ...
#
#       RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 1671                         2            80      0                  1
# 1672                         3            80      1                 15
# 1673                         4            80      0                  1
# 1674                         3            80      1                 21
# 1675                         2            80      0                  9
#
#       TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 1671                      3               1               1
# 1672                      3               3               3
# 1673                      0               4               1
# 1674                      3               3              21
# 1675                      5               2               8
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1671                  0                        0                     0
# 1672                  2                        1                     2
# 1673                  0                        0                     0
# 1674                  6                       11                     8
# 1675                  7                        0                     7
#
# [5 rows x 35 columns]

# %%
del data # For original dataset safety

# %%
df = df.select_dtypes(include='object')
display(df.shape)
df.sample(4)
# Out:
# (1676, 9)
#      Attrition     BusinessTravel  Department EducationField  Gender JobRole  \
# 1588        No  Travel_Frequently   Maternity        Medical    Male   Other
# 7           No      Travel_Rarely   Maternity  Life Sciences    Male   Nurse
# 27          No      Travel_Rarely  Cardiology      Marketing    Male   Nurse
# 1643        No      Travel_Rarely   Maternity  Life Sciences  Female   Nurse
#
#      MaritalStatus Over18 OverTime
# 1588       Married      Y      Yes
# 7         Divorced      Y       No
# 27         Married      Y       No
# 1643        Single      Y      Yes

# %%
df.drop(columns=['Over18'], inplace=True)
df.sample(6)
display(df.shape)
# Out:
# (1676, 8)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(sparse_output=False, handle_unknown='error', dtype='int64').set_output(transform='pandas')

# %% [markdown]
# ### Encoding Objects to Numerical Values

# %% [markdown]
# #### Gender and Department encoding (ohe) and merging

# %%
enc_gender = ohe.fit_transform(df[['Gender']])
enc_department = ohe.fit_transform(df[['Department']])

# %%
enc_gender.sample(5)
# Out:
#       Gender_Female  Gender_Male
# 1114              0            1
# 691               0            1
# 1368              0            1
# 1018              0            1
# 1620              1            0

# %%
enc_department.sample(4)
# Out:
#       Department_Cardiology  Department_Maternity  Department_Neurology
# 1170                      0                     1                     0
# 766                       0                     1                     0
# 1324                      1                     0                     0
# 176                       0                     1                     0

# %%
df = pd.concat([df, enc_department], axis=1).drop(columns=['Department'])
display(df.shape)
df.sample(5)
# Out:
# (1676, 10)
#      Attrition BusinessTravel EducationField  Gender         JobRole  \
# 1459        No     Non-Travel        Medical    Male       Therapist
# 973         No  Travel_Rarely  Life Sciences    Male       Therapist
# 1439        No  Travel_Rarely  Life Sciences    Male  Administrative
# 894         No  Travel_Rarely  Life Sciences  Female           Nurse
# 490         No  Travel_Rarely  Life Sciences  Female           Other
#
#      MaritalStatus OverTime  Department_Cardiology  Department_Maternity  \
# 1459        Single       No                      1                     0
# 973        Married      Yes                      0                     1
# 1439       Married       No                      0                     0
# 894         Single       No                      1                     0
# 490        Married       No                      0                     0
#
#       Department_Neurology
# 1459                     0
# 973                      0
# 1439                     1
# 894                      0
# 490                      1

# %%
df = pd.concat([df, enc_gender], axis=1).drop(columns=['Gender'])
display(df.shape)
df.sample(7)
# Out:
# (1676, 11)
#      Attrition     BusinessTravel    EducationField JobRole MaritalStatus  \
# 170         No      Travel_Rarely  Technical Degree   Other       Married
# 377         No      Travel_Rarely     Life Sciences   Other       Married
# 1262        No         Non-Travel  Technical Degree   Other      Divorced
# 1597        No  Travel_Frequently     Life Sciences   Nurse       Married
# 900         No      Travel_Rarely     Life Sciences   Nurse      Divorced
# 1488        No      Travel_Rarely     Life Sciences   Admin      Divorced
# 594         No      Travel_Rarely     Life Sciences   Other        Single
#
#      OverTime  Department_Cardiology  Department_Maternity  \
# 170       Yes                      0                     1
# 377        No                      0                     1
# 1262       No                      0                     1
# 1597       No                      0                     0
# 900       Yes                      0                     1
# 1488       No                      1                     0
# 594        No                      0                     1
#
#       Department_Neurology  Gender_Female  Gender_Male
# 170                      0              0            1
# 377                      0              1            0
# 1262                     0              0            1
# 1597                     1              0            1
# 900                      0              0            1
# 1488                     0              1            0
# 594                      0              1            0

# %% [markdown]
# #### OverTime and Attrition encoding (mapping to 1s and 0s)

# %%
# yes = 1 | no = 0 
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})  
df['OverTime'] = df['OverTime'].map({'Yes': 1, 'No': 0})

# %%
df.head(3)
# Out:
#    Attrition     BusinessTravel EducationField JobRole MaritalStatus  \
# 0          0      Travel_Rarely  Life Sciences   Nurse        Single
# 1          0  Travel_Frequently  Life Sciences   Other       Married
# 2          1      Travel_Rarely          Other   Nurse        Single
#
#    OverTime  Department_Cardiology  Department_Maternity  \
# 0         1                      1                     0
# 1         0                      0                     1
# 2         1                      0                     1
#
#    Department_Neurology  Gender_Female  Gender_Male
# 0                     0              1            0
# 1                     0              0            1
# 2                     0              0            1

# %% [markdown]
# #### Ordinal encoding for BusinessTravel and MaritalStatus

# %%
travel_frequency = ['Non-Travel', 'Travel_Rarely', 'Travel_Frequently'] # 0.0 = Non-Travel, 1.0 = Travel_Rarely, 2.0 = Travel_Frequently
marital_status = ['Single','Married', 'Divorced']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe_travel = OrdinalEncoder(categories=[travel_frequency])
oe_marital_status = OrdinalEncoder(categories= [marital_status])

# %%
df['BusinessTravel'] = oe_travel.fit_transform(df[['BusinessTravel']]).astype('int64')

# %%
df['MaritalStatus'] = oe_marital_status.fit_transform(df[['MaritalStatus']]).astype('int64')

# %%
df.sample(10)
# Out:
#       Attrition  BusinessTravel    EducationField    JobRole  MaritalStatus  \
# 283           0               1  Technical Degree      Nurse              1
# 1391          1               2         Marketing      Nurse              1
# 249           0               2     Life Sciences  Therapist              1
# 560           1               1             Other      Other              0
# 80            0               1     Life Sciences      Nurse              1
# 1227          0               1           Medical      Nurse              2
# 784           0               2     Life Sciences  Therapist              1
# 439           1               2   Human Resources      Other              2
# 467           0               1  Technical Degree      Other              2
# 1596          0               1           Medical      Nurse              1
#
#       OverTime  Department_Cardiology  Department_Maternity  \
# 283          1                      0                     1
# 1391         1                      1                     0
# 249          0                      0                     0
# 560          1                      0                     1
# 80           1                      0                     1
# 1227         0                      0                     1
# 784          0                      0                     0
# 439          1                      0                     0
# 467          1                      0                     1
# 1596         0                      0                     0
#
#       Department_Neurology  Gender_Female  Gender_Male
# 283                      0              0            1
# 1391                     0              0            1
# 249                      1              0            1
# 560                      0              0            1
# 80                       0              0            1
# 1227                     0              0            1
# 784                      1              0            1
# 439                      1              1            0
# 467                      0              0            1
# 1596                     1              1            0

# %%
print(f'Attrition      = {df.Attrition.unique()}')
print(f'OverTime       = {df.OverTime.unique()}')
print(f'Gender         = {df.Gender_Male.unique()}')
print(f'Gender         = {df.Gender_Female.unique()}')
print(f'Department     = {df.Department_Cardiology.unique()}')
print(f'Department     = {df.Department_Maternity.unique()}')
print(f'Department     = {df.Department_Neurology.unique()}')
print(f'BusinessTravel = {df.BusinessTravel.unique()}')
print(f'MaritalStatus = {df.MaritalStatus.unique()}')
print(f'EducationField = {df.EducationField.unique()}')
print(f'JobRole        = {df.JobRole.unique()}')
# Out:
# Attrition      = [0 1]
# OverTime       = [1 0]
# Gender         = [0 1]
# Gender         = [1 0]
# Department     = [1 0]
# Department     = [0 1]
# Department     = [0 1]
# BusinessTravel = [1 2 0]
# MaritalStatus = [0 1 2]
# EducationField = ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# JobRole        = ['Nurse' 'Other' 'Therapist' 'Administrative' 'Admin']
